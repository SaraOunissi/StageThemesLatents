# %% [markdown]
# On commence par importer certaines bibliothèques.

# %%
from lxml import html
import requests 
import re
from lxml import etree

# %% [markdown]
# Maintenant on va générer les liens des pages du 1 janvier 2010 à aujourd'hui. Pour ce faire on va utiliser la bibliothèque datetime et timedelta, et simplement faire une boucle sur la periode qui nous interesse.
# Sans oublier de passer le nom des mois en français car de base dans la bibliotheque il est en anglais.

# %%
Days = []
from datetime import datetime, timedelta as td

Mois=['janvier','fevrier','mars','avril','mai','juin','juillet','aout','septembre','octobre','novembre','decembre']#pour obtenir les mois en francais
d1 = datetime(2010, 1, 1)
d2 = datetime.now()
delta = d2 - d1
site = 'http://www.ouest-france.fr/archives/'

for i in range(delta.days + 1):
    day_i = d1 + td(days=i)
    month = day_i.date().month
    mois_i = Mois[month-1]
    Days.append(site+day_i.strftime('%Y')+'/'+day_i.strftime('%d')+'-'+mois_i+'-'+day_i.strftime('%Y')+'/')

#Test liste url de chaque jour
Days
# Out:
# ['http://www.ouest-france.fr/archives/2010/01-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/02-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/03-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/04-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/05-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/06-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/07-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/08-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/09-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/10-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/11-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/12-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/13-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/14-janvier-2010/',
#  'http://www.ouest-france.fr/archives/2010/15-janvier-2010/',
# ...

# %% [markdown]
# Maintenant on veut récupérer les articles de chaque jour dans Articles

# %%
Articles = []

for i in range(0, len(Days)):
    page3=requests.get(Days[i])
    tree3 = html.fromstring(page3.content)
    liste3=tree3.xpath('//section[@class="list-t3 add-icon"]/ul/li/article/a')
    for j in range(0,len(liste3)):
        Articles.append('http://www.ouest-france.fr'+liste3[j].get("href"))

#Test 
for i in range (0, 10):
    print Articles[i]
# Out:
# http://www.ouest-france.fr/pays-de-la-loire/la-fleche-72200/la-sarthe-compte-556-946-habitants-496138
# http://www.ouest-france.fr/pays-de-la-loire/nantes-44000/incendies-de-voitures-la-nuit-du-reveillon-comme-lan-dernier-496140
# http://www.ouest-france.fr/bretagne/brest-29200/brest-72-sorties-des-pompiers-durant-la-nuit-du-nouvel-496141
# http://www.ouest-france.fr/normandie/alencon-61000/un-train-en-panne-pres-de-caen-retarde-tout-le-trafic-496143
# http://www.ouest-france.fr/normandie/alencon-61000/demain-alencon-celebre-lanniversaire-de-sainte-therese-496145
# http://www.ouest-france.fr/la-turquie-veut-recuperer-les-restes-de-saint-nicolas-496175
# http://www.ouest-france.fr/pays-de-la-loire/nantes-44000/nuit-chaude-saint-nazaire-496147
# http://www.ouest-france.fr/dubai-inaugure-la-plus-haute-tour-du-monde-496192
# http://www.ouest-france.fr/coups-de-couteau-mortels-fougeres-496164
# ...

# %% [markdown]
# Maintenant on veut enregistrer la liste des urls qui sont dans la liste Articles

# %%
from tempfile import TemporaryFile
import numpy 

url = TemporaryFile()

numpy.save('url',Articles)

import pickle

with open('url', 'wb') as f:
    pickle.dump(Articles, f)

# %% [markdown]
# Je lance scrapy manuellement dans mon repository Github : scrapy startproject articles, dans OF (pour Ouest-France)
# Puis je cree un fichier dans le dossier spider ou je mets le code précedent et le bout de code ci dessous. Enfin je lance scrapy crowl dans la console manuellement pour récupérer les fichiers html.

# %%
import scrapy
import pickle

with open('url', 'rb') as f:#url doit etre dans first
    my_list = pickle.load(f)

class FirstSpider(scrapy.Spider):
    name = "articles"
    allowed_domains = ["ouest-france.fr"]
    start_urls = my_list

    def parse(self, response):
        filename = response.url.split("/")[-2] + '.html'
        with open(filename, 'wb') as f:
            f.write(response.body)

# %% [markdown]
# On a tous les fichiers html dans le repertoire courant. On va récuperer le nom de tous les fichier html du repertoire courant et les mettre dans une liste Lhtml.

# %%
import os
Lhtml=[]
for file in os.listdir("c:/Users/Sara/Documents/GitHub/StageRICM4/StageThemesLatents/OF/articles"):
    if file.endswith(".html"):
        Lhtml.append(file)
Lhtml
# Out:
# ['11-novembre.html',
#  '1er-mai.html',
#  'a83.html',
#  'abbaretz-44170.html',
#  'ablon-14600.html',
#  'acigne-35690.html',
#  'acqueville-14220.html',
#  'aeronautique.html',
#  'affaire-cahuzac.html',
#  'affaire-jouyet.html',
#  'affaire-leonarda.html',
#  'affaire-tapie.html',
#  'afghanistan.html',
#  'afrique-du-sud.html',
#  'agneaux-50180.html',
#  'agon-coutainville-50230.html',
#  'agriculture.html',
#  'ahuille-53940.html',
#  'aigne-72650.html',
#  'aignerville-14710.html',
#  'aigrefeuille-sur-maine-44140.html',
#  'aillieres-beauvoir-72600.html',
#  'ain.html',
#  'airan-14370.html',
#  'airel-50680.html',
#  'aisne.html',
#  'aizenay-85190.html',
#  'albanie.html',
#  'alencon-61000.html',
#  'alexain-53240.html',
#  'algerie.html',
#  'allaire-56350.html',
#  'allemagne.html',
#  'allier.html',
#  'allineuc-22460.html',
#  'allonnes-49650.html',
#  'allonnes-72700.html',
#  'almeneches-61570.html',
#  'alpes-de-haute-provence.html',
#  'alpes-maritimes.html',
# ...

# %% [markdown]
# Maintenant on va ouvrir les fichiers html 1 par 1, on va les traiter avec BeautifulSoup pour en extraire seulement le contenu dans la balise div class="article-content". Ensuite on récupère ce texte, on l'encode en utf8 et on le sauve dans un fichier txt portant le même nom que le fichier html de départ.

# %%
import re
import codecs

for i in range(0, len(Lhtml)):
    htmlfile=open('C:/Users/Sara/Documents/GitHub/StageRICM4/StageThemesLatents/OF/articles/'+Lhtml[i])
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(htmlfile, 'html.parser')

    ListDiv=soup.find_all('div')
    index=0
    for m in range(0,len(ListDiv)):
        if re.search('article-content',str(ListDiv[m].get("class"))):
            index=m
    #print(ListDiv[index].get_text())

    s=ListDiv[index].get_text()
    sout=s.encode("utf8")
    name=Lhtml[i].split(".")
    with codecs.open('./OF/TXT/'+name[0]+".txt", 'w', encoding='utf8') as out:     
        out.write("%sout"%sout.decode("utf8"))
